# %%
import tricahue
! pip show tricahue
# Out:
# Name: tricahue
# Version: 0.0b5
# Summary: This package extracts experimental data and metadata, converts to stardard formats, uploads to SynBioHub and Flapjack, and connects them
# Home-page:
# Author:
# Author-email: Gonzalo Vidal <gonzalo.vidalpena@colorado.edu>
# License:
# Location: c:\users\smf12\spur\venv_39\lib\site-packages
# Requires: excel2flapjack, excel2sbol, numpy, pandas
# Required-by:

# %%
input_excel_path = '../tests/test_files/Tricahue_v11.6b_Medias.xlsx'
# fj_url = 'localhost:8000'
fj_url = 'charmmefj-api.synbiohub.org'
fj_user = None
fj_pass = None
sbh_url =  'https://synbiohub.org'
sbh_user = None
sbh_pass = None
sbh_collection = 'XDC_Upload_Test'
sbh_collection_description = 'Collection made using tricahue',
sbh_overwrite = 1
fj_overwrite = 0
homespace = 'https://example.org'
fj_token = None
sbh_token = None
attachments = {'ExampleMedia':'../images/example.jpg',
               'LB':'../tests/test_files/ExpNOTs_GFP.xlsx'}

# %%
# weird random to-dos
# overwrite - sbh works sort of; fj DOES NOT work
# test with id != name in template

# %% [markdown]
# User/Password

# %%
fj_user = 'test'
fj_pass = 'test123'

# %%
sbh_user = 'synbiotest'
sbh_pass = 'test123'

# %% [markdown]
# Token

# %%
fj_token = ''
sbh_token = ''

# %% [markdown]
# Run:

# %%
xdc = tricahue.XDC(input_excel_path,
                    fj_url,
                    fj_user,
                    fj_pass,
                    sbh_url,
                    sbh_user,
                    sbh_pass,
                    sbh_collection,
                    sbh_collection_description,
                    sbh_overwrite,
                    fj_overwrite,
                    fj_token, 
                    sbh_token, 
                    homespace,
                    attachments)

print(xdc.run())
# Out:
# Starting XDC run
# No user logged in.
# Processing the welcome page...
# Welcome Page Metadata:
# Author: Gonzalo Vidal
# Email: gonzalo.vidalpena@colorado.edu
# Lab: Genetic Logic Lab
# Institution: University of Colorado Boulder
# Library Name: medias
# Description: Repository of medias
# PubId:
# Date:
# Final: False
# Domain:
# Master Collection:
# Conversion will happen with sbol version 2 as specified in the excel sheet
# Media
# id 1
# name LB
# description Rich Broth
# sboluri
#
# id 2
# name PBS
# description Phosphate Buffered Saline
# sboluri
#
# id 3
# name Water
# description Water
# sboluri
#
# id 4
# name Example media
# description Upload example
# sboluri
#
# Sheet Media does not correspond to a valid flapjack object
# Uploaded attachment example.jpg: 200
# Uploaded attachment ExpNOTs_GFP.xlsx: 200
# XDC run complete
# https://synbiohub.org/user/synbiotest/XDC_Upload_Test/XDC_Upload_Test_collection/1
