# %%
import tricahue
! pip show tricahue

# %%
input_excel_path = '../tests/test_files/Tricahue_v11.6b_Medias.xlsx'
fj_url = 'charmmefj-api.synbiohub.org'
fj_user = None
fj_pass = None 
sbh_url =  'https://synbiohub.org'
sbh_user = None
sbh_pass = None
sbh_collection = 'XDC_Upload_Test'
sbh_collection_description = 'Collection made using tricahue',
sbh_overwrite = 0
fj_overwrite = 0
homespace = 'https://synbiohub.org/gonza10v'
fj_token = None
sbh_token = None

# %%
# weird random to-dos
# - homespace from template? check
# overwrite
# test with id != name in template

# %% [markdown]
# User/Password

# %%
# fj_user = 'test' 
# fj_pass = 'test123' 
sbh_user = 'test@test.test'
sbh_pass = 'test123'

# %% [markdown]
# Token login, both SBH and FJ

# %%
fj_token = ''
sbh_token = ''

# %% [markdown]
# Run:

# %%
xdc = tricahue.XDC(input_excel_path,
                    fj_url,
                    fj_user,
                    fj_pass,
                    sbh_url,
                    sbh_user,
                    sbh_pass,
                    sbh_collection,
                    sbh_collection_description,
                    sbh_overwrite,
                    fj_overwrite,
                    fj_token, 
                    sbh_token, 
                    homespace)

print(xdc.run())
