# %%
import tricahue
import os
import getpass
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import tricahue
#       2 import os
#       3 import getpass
#
# ModuleNotFoundError: No module named 'tricahue'

# %% [markdown]
# # XDC Test

# %%
fj_url = "charmmefj-api.synbiohub.org"
fj_user = input()
fj_pass = getpass.getpass()

# %%
sbh_url = "https://synbiohub.org"
sbh_user = "test@test.test"
sbh_pass = "test123"
sbh_collec = "XDC_package_test_medias"

# %%
test_file_path ='../tests/test_files'
excel_path = os.path.join(test_file_path, 'Tricahue_v11.6b_Medias.xlsm')

homespace = 'https://synbiohub.org/gonza10v'

fj_overwrite = False
sbh_overwrite=False

# %%
xdc = tricahue.XDC(input_excel_path = excel_path,
            fj_url = "charmmefj-api.synbiohub.org",
            fj_user = None, 
            fj_pass = None, 
            sbh_url = "synbiohub.org", 
            sbh_user = None, 
            sbh_pass = None, 
            sbh_collection = sbh_collec, 
            sbh_collection_description = 'Collection made using tricahue',
            sbh_overwrite = sbh_overwrite, 
            fj_overwrite = fj_overwrite, 
            homespace = homespace,
            fj_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzU0NTAyNDUwLCJqdGkiOiJhMmFjYzlhMTNlYWY0NzU1OWRkMzQ4MzYyNjMxNTc4YSIsInVzZXJfaWQiOjJ9.qfEXHlTKN6KyYXZiIjLxiNxPhgHhc4f6r-caJhencNk", 
            sbh_token = "3e293de1-6181-47d3-a104-4312182fb675")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 xdc = tricahue.XDC(input_excel_path = excel_path,
#       2             fj_url = "charmmefj-api.synbiohub.org",
#       3             fj_user = None,
#       4             fj_pass = None,
#       5             sbh_url = "synbiohub.org",
#       6             sbh_user = None,
#       7             sbh_pass = None,
#       8             sbh_collection = sbh_collec,
#       9             sbh_collection_description = 'Collection made using tricahue',
#      10             sbh_overwrite = sbh_overwrite,
#      11             fj_overwrite = fj_overwrite,
#      12             homespace = homespace,
#      13             fj_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzU0NTAyNDUwLCJqdGkiOiJhMmFjYzlhMTNlYWY0NzU1OWRkMzQ4MzYyNjMxNTc4YSIsInVzZXJfaWQiOjJ9.qfEXHlTKN6KyYXZiIjLxiNxPhgHhc4f6r-caJhencNk",
#      14             sbh_token = "3e293de1-6181-47d3-a104-4312182fb675")
#
# NameError: name 'tricahue' is not defined

# %%
xdc.initialize()

# %%
print(xdc.fj_token)
# Out:
# None

# %%
xdc.log_in_fj()
# Out:
# No user logged in.

# %%
print(xdc.fj_token)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzQ3MzI2MzY2LCJqdGkiOiI5YTE2ZDE2YjllYjQ0NjVlOWM0Mjk5ZWM2N2VhZTBiMiIsInVzZXJfaWQiOjJ9.DBLw5uBCc-S5NYhsR7lDtZaNWeQahHvmKhIZqwP8Yrc

# %%
xdc.log_in_sbh()

# %%
xdc.sbh_token
# Out:
# '45c8477a-c04a-4043-8074-853e8797f406'

# %%
xdc.convert_to_sbol()
# Out:
# /Users/gonzalovidal/opt/anaconda3/envs/GLLDB/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning:
#
# Data Validation extension is not supported and will be removed
# Processing the welcome page...
# Welcome Page Metadata:
# Author: Gonzalo Vidal
# Email: gonzalo.vidalpena@colorado.edu
# Lab: Genetic Logic Lab
# Institution: University of Colorado Boulder
# Library Name: medias
# Description: Repository of medias
# PubId:
# Date:
# Final: False
# Domain:
# Master Collection:
# Conversion will happen with sbol version 2 as specified in the excel sheet
# Media

# %%
for tl in xdc.sbol_doc:
    print(tl)
# Out:
# https://synbiohub.org/gonza10v/LB/1
# https://synbiohub.org/gonza10v/PBS/1
# https://synbiohub.org/gonza10v/Water/1

# %%
xdc.sbol_hash_map
# Out:
# {}

# %%
xdc.generate_sbol_hash_map()

# %%
xdc.sbol_hash_map
# Out:
# {'LB': 'https://synbiohub.org/user/synbiotest/XDC_package_test_medias//LB/1',
#  'PBS': 'https://synbiohub.org/user/synbiotest/XDC_package_test_medias//PBS/1',
#  'Water': 'https://synbiohub.org/user/synbiotest/XDC_package_test_medias//Water/1'}

# %%
xdc.x2f.index_skiprows = 0

# %%
xdc.x2f.generate_sheets_to_object_mapping()
# Out:
# {'Media': 'Media'}

# %%
xdc.upload_to_fj()
# Out:
# Returning exististing model, media
# id 3
# name LB
# description Rich Broth
# sboluri
#
# Returning exististing model, media
# id 4
# name PBS
# description Phosphate Buffered Saline
# sboluri
#
# Returning exististing model, media
# id 5
# name Water
# description Water
# sboluri
#
# Sheet Media does not correspond to a valid flapjack object

# %%
xdc.x2f.index_skiprows = 3

# %%
xdc.x2f.index_skiprows
# Out:
# 3

# %%
xdc.upload_to_fj()
# Out:
# Returning exististing model, media
# id 3
# name LB
# description Rich Broth
# sboluri
#
# Returning exististing model, media
# id 4
# name PBS
# description Phosphate Buffered Saline
# sboluri
#
# Returning exististing model, media
# id 5
# name Water
# description Water
# sboluri

# %%
xdc.x2f.df
# Out:
#            name                description object flapjackid sbol_uri
# Media ID
# LB           LB                 Rich Broth  Media          3
# PBS         PBS  Phosphate Buffered Saline  Media          4
# Water     Water                      Water  Media          5

# %%
xdc.sbol_doc

# %%
xdc.upload_to_sbh()
# Out:
# 'https://synbiohub.org/user/synbiotest/XDC_package_test_medias/XDC_package_test_medias_collection/1'

# %%
#complete run

xdc.log_in_fj()
xdc.log_in_sbh()
xdc.convert_to_sbol()
xdc.x2f.sheets = ['Media']
xdc.x2f.index_skiprows = 3
xdc.generate_sbol_hash_map()
xdc.upload_to_fj()
xdc.upload_to_sbh()
# Out:
# Processing the welcome page...
# Welcome Page Metadata:
# Author: Gonzalo Vidal
# Email: gonzalo.vidalpena@colorado.edu
# Lab: Genetic Logic Lab
# Institution: University of Colorado Boulder
# Library Name: medias
# Description: Repository of medias
# PubId:
# Date:
# Final: False
# Domain:
# Master Collection:
# Conversion will happen with sbol version 2 as specified in the excel sheet
# Media
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 9
#       7 xdc.x2f.index_skiprows = 3
#       8 xdc.generate_sbol_hash_map()
# ----> 9 xdc.upload_to_fj()
#      10 xdc.upload_to_sbh()
#
# File ~/Documents/GitHub/Tricahue/src/tricahue.py:189, in XDC.upload_to_fj(self)
#     187 def upload_to_fj(self, ):
#     188     self.x2f.create_df()
# --> 189     self.x2f.upload_medias()
#
# File ~/opt/anaconda3/envs/GLLDB/lib/python3.9/site-packages/excel2flapjack/main.py:220, in X2F.upload_medias(self)
#     218 del_inds = []
#     219 for index, row in self.df[self.df['object'] == 'Media'].iterrows():
# --> 220     fj_obj = self.fj.create(
#     221         'media',
#     222         name=row['name'],
#     223         description=row['description'],
#     224         confirm=self.confirm,
#     225         overwrite=self.overwrite,
#     226     )
#     227     for i in fj_obj:
#     228         print(i, fj_obj[i][0])
#
# File ~/Documents/GitHub/pyFlapjack/src/flapjack/flapjack.py:167, in Flapjack.create(self, model, confirm, overwrite, **kwargs)
#     165 if confirm and overwrite:
#     166     raise ValueError('Cannot confirm and overwrite at the same time.')
# --> 167 self.refresh()
#     168 url = self.http_url_base + f'/api/{model}/'
#     169 existing = self.get(model, **kwargs)
#
# File ~/Documents/GitHub/pyFlapjack/src/flapjack/flapjack.py:147, in Flapjack.refresh(self)
#     142 def refresh(self):
#     143     s = requests.post(
#     144         self.http_url_base+'/api/auth/refresh/',
#     145         data={'refresh': self.refresh_token}
#     146     )
# --> 147     self.access_token = s.json()['access']
#
# KeyError: 'access'

# %% [markdown]
# # The End
