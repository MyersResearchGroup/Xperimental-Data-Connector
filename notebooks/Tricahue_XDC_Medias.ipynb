# %%
import tricahue
import os
import getpass

# %% [markdown]
# # XDC Test

# %%
fj_url = "charmmefj-api.synbiohub.org"
fj_user = input()
fj_pass = getpass.getpass()

# %%
sbh_url = "https://synbiohub.org"
sbh_user = "test@test.test"
sbh_pass = "test123"
sbh_collec = "XDC_package_test_medias"

# %%
test_file_path ='../tests/test_files'
excel_path = os.path.join(test_file_path, 'Tricahue_v11.6b_Medias.xlsx')

homespace = 'https://synbiohub.org/gonza10v'

fj_overwrite = 1
sbh_overwrite = 1

# %%
# for testing: True for token, False for user/password 
token = False

if not token:
    xdc = tricahue.XDC(input_excel_path = excel_path,
            fj_url = fj_url,
            fj_user = fj_user, 
            fj_pass = fj_pass, 
            sbh_url = sbh_url, 
            sbh_user = sbh_user, 
            sbh_pass = sbh_pass, 
            sbh_collection = sbh_collec, 
            sbh_collection_description = 'Collection made using tricahue',
            sbh_overwrite = sbh_overwrite, 
            fj_overwrite = fj_overwrite, 
            homespace = homespace,
            fj_token = None,
            sbh_token = None)

else: 
    xdc = tricahue.XDC(input_excel_path = excel_path,
            fj_url = fj_url,
            fj_user = None, 
            fj_pass = None, 
            sbh_url = sbh_url, 
            sbh_user = sbh_user, 
            sbh_pass = sbh_pass, 
            sbh_collection = sbh_collec, 
            sbh_collection_description = 'Collection made using tricahue',
            sbh_overwrite = sbh_overwrite, 
            fj_overwrite = fj_overwrite, 
            homespace = homespace,
            fj_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTc1MTU1NDc4NSwianRpIjoiZGFmMTEwMzFjZTE1NDY2ZTllZDA0ZDFjZmQyYWI0ZTkiLCJ1c2VyX2lkIjoxfQ.Lo5cXqEtfB0AcJKsRdjKWoC6e55kEdNmo_oOxzGTQtk", 
            sbh_token = None)

# %%
xdc.initialize()

# %%
xdc.fj_token

# %%
xdc.log_in_fj()
# Out:
# No user logged in.

# %%
xdc.fj_token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTc1OTU5MTAxNiwianRpIjoiNmFiODk2YWIwNDg1NDZiNmE4OWMxZDA1OTczM2UyNzAiLCJ1c2VyX2lkIjoyfQ.ssL_QjOsl5l3sLNfGvw0CMgU5UhIj2tJARRZH-4odSU'

# %%
xdc.log_in_sbh()

# %%
xdc.sbh_token
# Out:
# '046ef56a-815d-45a4-abee-2d74a88d64cc'

# %%
xdc.convert_to_sbol()
# Out:
# Processing the welcome page...
# Welcome Page Metadata:
# Author: Gonzalo Vidal
# Email: gonzalo.vidalpena@colorado.edu
# Lab: Genetic Logic Lab
# Institution: University of Colorado Boulder
# Library Name: medias
# Description: Repository of medias
# PubId:
# Date:
# Final: False
# Domain:
# Master Collection:
# Conversion will happen with sbol version 2 as specified in the excel sheet
# Media

# %%
for tl in xdc.sbol_doc:
    print(tl)
# Out:
# https://synbiohub.org/gonza10v/LB/1
# https://synbiohub.org/gonza10v/PBS/1
# https://synbiohub.org/gonza10v/Water/1

# %%
xdc.sbol_hash_map
# Out:
# {}

# %%
xdc.generate_sbol_hash_map()

# %%
xdc.sbol_hash_map
# Out:
# {'LB': 'https://synbiohub.org/user/synbiotest/XDC_package_test_medias/LB/1',
#  'PBS': 'https://synbiohub.org/user/synbiotest/XDC_package_test_medias/PBS/1',
#  'Water': 'https://synbiohub.org/user/synbiotest/XDC_package_test_medias/Water/1'}

# %%
xdc.x2f.index_skiprows = 0

# %%
xdc.x2f.generate_sheets_to_object_mapping()
# Out:
# {'Media': 'Media'}

# %%
xdc.upload_to_fj()
# Out:
# id 7
# name LB
# description Rich Broth
# sboluri
#
# id 9
# name PBS
# description Phosphate Buffered Saline
# sboluri
#
# id 11
# name Water
# description Water
# sboluri

# %%
xdc.x2f.index_skiprows = 3

# %%
xdc.x2f.index_skiprows
# Out:
# 3

# %%
xdc.x2f.df
# Out:
#            name                description object flapjackid  \
# Media ID
# LB           LB                 Rich Broth  Media          7
# PBS         PBS  Phosphate Buffered Saline  Media          9
# Water     Water                      Water  Media         11
#
#                                                    sbol_uri
# Media ID
# LB        https://synbiohub.org/user/synbiotest/XDC_pack...
# PBS       https://synbiohub.org/user/synbiotest/XDC_pack...
# Water     https://synbiohub.org/user/synbiotest/XDC_pack...

# %%
xdc.sbol_doc

# %%
xdc.upload_to_sbh()
# Out:
# 'https://synbiohub.org/user/synbiotest/XDC_package_test_medias/XDC_package_test_medias_collection/1'

# %%
#complete run

# xdc.log_in_fj()
# xdc.log_in_sbh()
# xdc.convert_to_sbol()
# xdc.x2f.sheets = ['Media']
# xdc.x2f.index_skiprows = 3
# xdc.generate_sbol_hash_map()
# xdc.upload_to_fj()
# xdc.upload_to_sbh()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 5
#       3 xdc.log_in_fj()
#       4 xdc.log_in_sbh()
# ----> 5 xdc.convert_to_sbol()
#       6 xdc.x2f.sheets = ['Media']
#       7 xdc.x2f.index_skiprows = 3
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\tricahue.py:138, in XDC.convert_to_sbol(self, sbol_version)
#     137 def convert_to_sbol(self, sbol_version=2):
# --> 138     excel2sbol.converter(file_path_in = self.input_excel_path,
#     139             file_path_out = self.file_path_out, homespace=self.homespace, sbol_version=sbol_version)
#     140     doc = sbol2.Document()
#     141     doc.read(self.file_path_out)
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\excel2sbol\converter.py:21, in converter(file_path_in, file_path_out, sbol_version, homespace, file_format, username, password, url)
#      18     os.environ["SBOL_PASSWORD"] = password
#      19     os.environ["SBOL_URL"] = url
# ---> 21 col_read_df, to_convert, compiled_sheets, version_info, homespace2 = e2s.initialise(file_path_in)
#      22 dict = e2s.initialise_welcome(file_path_in)
#      23 for key, value in dict.items():
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\excel2sbol\compiler.py:139, in initialise(file_path_in)
#     136     compiled_sheets[sheet_name] = sheet_dict
#     138 # read in column_dict sheet
# --> 139 col_read_df = pd.read_excel(file_path_in,
#     140                             sheet_name="column_definitions", header=0,
#     141                             engine='openpyxl')
#     142 col_read_df = col_read_df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#     144 # processing to turn init columns into 'sheet' columns
#     145 # pull all column names
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\pandas\io\excel\_base.py:364, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362 if not isinstance(io, ExcelFile):
#     363     should_close = True
# --> 364     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365 elif engine and engine != io.engine:
#     366     raise ValueError(
#     367         "Engine should not be specified when passing "
#     368         "an ExcelFile - ExcelFile already has the engine set"
#     369     )
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\pandas\io\excel\_base.py:1233, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1230 self.engine = engine
#    1231 self.storage_options = storage_options
# -> 1233 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\pandas\io\excel\_openpyxl.py:522, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     511 """
#     512 Reader using openpyxl engine.
#     513
#    (...)
#     519     passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     520 """
#     521 import_optional_dependency("openpyxl")
# --> 522 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\pandas\io\excel\_base.py:420, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     418 self.handles.handle.seek(0)
#     419 try:
# --> 420     self.book = self.load_workbook(self.handles.handle)
#     421 except Exception:
#     422     self.close()
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\pandas\io\excel\_openpyxl.py:533, in OpenpyxlReader.load_workbook(self, filepath_or_buffer)
#     530 def load_workbook(self, filepath_or_buffer: FilePathOrBuffer):
#     531     from openpyxl import load_workbook
# --> 533     return load_workbook(
#     534         filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     535     )
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\openpyxl\reader\excel.py:317, in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     290 """Open the given filename and return the workbook
#     291
#     292 :param filename: the path to open or a file-like object
#    (...)
#     313
#     314 """
#     315 reader = ExcelReader(filename, read_only, keep_vba,
#     316                     data_only, keep_links)
# --> 317 reader.read()
#     318 return reader.wb
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\openpyxl\reader\excel.py:277, in ExcelReader.read(self)
#     275 def read(self):
#     276     self.read_manifest()
# --> 277     self.read_strings()
#     278     self.read_workbook()
#     279     self.read_properties()
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\openpyxl\reader\excel.py:144, in ExcelReader.read_strings(self)
#     142 strings_path = ct.PartName[1:]
#     143 with self.archive.open(strings_path,) as src:
# --> 144     self.shared_strings = read_string_table(src)
#
# File c:\Users\smf12\SPUR\venv_39\lib\site-packages\openpyxl\reader\strings.py:15, in read_string_table(xml_source)
#      12 strings = []
#      13 STRING_TAG = '{%s}si' % SHEET_MAIN_NS
# ---> 15 for _, node in iterparse(xml_source):
#      16     if node.tag == STRING_TAG:
#      17         text = Text.from_tree(node).content
#
# File ~\AppData\Local\Programs\Python\Python39\lib\xml\etree\ElementTree.py:1257, in iterparse.<locals>.iterator(source)
#    1255 yield from pullparser.read_events()
#    1256 # load event buffer
# -> 1257 data = source.read(16 * 1024)
#    1258 if not data:
#    1259     break
#
# File ~\AppData\Local\Programs\Python\Python39\lib\zipfile.py:924, in ZipExtFile.read(self, n)
#     922 self._offset = 0
#     923 while n > 0 and not self._eof:
# --> 924     data = self._read1(n)
#     925     if n < len(data):
#     926         self._readbuffer = data
#
# File ~\AppData\Local\Programs\Python\Python39\lib\zipfile.py:1000, in ZipExtFile._read1(self, n)
#     998 elif self._compress_type == ZIP_DEFLATED:
#     999     n = max(n, self.MIN_READ_SIZE)
# -> 1000     data = self._decompressor.decompress(data, n)
#    1001     self._eof = (self._decompressor.eof or
#    1002                  self._compress_left <= 0 and
#    1003                  not self._decompressor.unconsumed_tail)
#    1004     if self._eof:
#
# KeyboardInterrupt:

# %% [markdown]
# # The End
